# %%
# !pip install -r requirements.txt

# %%
import scanpy as sc

# %%
adata = sc.read_h5ad('adata_small_test.h5ad')

# %%
print(adata)
# Out:
# AnnData object with n_obs × n_vars = 1019 × 20138
#     obs: 'age', 'cell', 'cell_ontology_class', 'cell_ontology_id', 'free_annotation', 'method', 'mouse.id', 'n_genes', 'sex', 'subtissue', 'tissue', 'tissue_free_annotation'
#     var: 'n_cells'

# %%
print(adata.obs.head())
# Out:
#                            age                        cell  \
# index
# AGCTCCTCAGACTCGC-1-16-1-0  30m  10X_P1_16_AGCTCCTCAGACTCGC
# CCGGTAGAGGAATTAC-1-27-1-0  30m  10X_P2_10_CCGGTAGAGGAATTAC
# CGTGTCTGTAGCCTCG-1-27-1-0  30m  10X_P2_10_CGTGTCTGTAGCCTCG
# CTAGTGAGTGATGCCC-1-27-1-0  30m  10X_P2_10_CTAGTGAGTGATGCCC
# GGATGTTTCCAGATCA-1-27-1-0  30m  10X_P2_10_GGATGTTTCCAGATCA
#
#                           cell_ontology_class cell_ontology_id  \
# index
# AGCTCCTCAGACTCGC-1-16-1-0          hepatocyte               NA
# CCGGTAGAGGAATTAC-1-27-1-0          hepatocyte               NA
# CGTGTCTGTAGCCTCG-1-27-1-0          hepatocyte               NA
# CTAGTGAGTGATGCCC-1-27-1-0          hepatocyte               NA
# GGATGTTTCCAGATCA-1-27-1-0          hepatocyte               NA
#
#                                                    free_annotation   method  \
# index
# AGCTCCTCAGACTCGC-1-16-1-0  Hepatocyte (Pericentral and Periportal)  droplet
# ...

# %%
print(adata.var.head())
# Out:
#         n_cells
# index
# Xkr4        147
# Rp1         233
# Sox17     27289
# Mrpl15    95312
# Lypla1    86096

# %%
print(adata.X.shape)
# Out:
# (1019, 20138)

# %%
print(adata.X[:5, :5].toarray())
# Out:
# [[0. 0. 0. 1. 0.]
#  [0. 0. 0. 0. 3.]
#  [0. 0. 0. 0. 2.]
#  [0. 0. 0. 2. 5.]
#  [0. 0. 0. 0. 1.]]

# %%
print(adata.X[:5, :5])
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float32'
# 	with 6 stored elements and shape (5, 5)>
#   Coords	Values
#   (0, 3)	1.0
#   (1, 4)	3.0
#   (2, 4)	2.0
#   (3, 3)	2.0
#   (3, 4)	5.0
#   (4, 4)	1.0

# %%
# Plot UMAP to visualize cell clusters (optional)
sc.pp.neighbors(adata)
sc.tl.umap(adata)
sc.pl.umap(adata, color=['cell_ontology_class', 'age'])
# Out:
# /opt/homebrew/anaconda3/lib/python3.12/site-packages/scanpy/neighbors/__init__.py:586: UserWarning: You’re trying to run this on 20138 dimensions of `.X`, if you really want this, set `use_rep='X'`.
#          Falling back to preprocessing with `sc.pp.pca` and default params.
#   X = _choose_representation(self._adata, use_rep=use_rep, n_pcs=n_pcs)
